# %%
import sys
if ('./Package') not in sys.path: sys.path.append('./Package')
from Test.unit_test import UnitTest, MultipleActionTest
from Strategys.Stochastic_Rsi_Macd import Stochastic_RSI_MACD
import requests
import pandas as pd

# %%
def list_top_volume_crypto():
    url_link = 'https://finance.yahoo.com/u/yahoo-finance/watchlists/crypto-top-volume-24hr/'
    r = requests.get(url_link,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
    top_volume_crypto = pd.read_html(r.text)[1]
    labels = list(top_volume_crypto['Symbol'])
    return labels

# %%
Test = MultipleActionTest(list_top_volume_crypto(), Stochastic_RSI_MACD())

# %%
profits = Test.execute

# %%
df = pd.DataFrame(profits, columns=['Crypto', 'Profit'])
df.sort_values(by='Profit',ascending=False)
# Out:
#        Crypto     Profit
# 6    SOL1-USD  52.314651
# 2     ADA-USD  36.223801
# 11   AVAX-USD  26.024634
# 8    DOGE-USD  21.562849
# 12  LUNA1-USD  18.872295
# 16   ALGO-USD  17.446179
# 13   LINK-USD  16.669880
# 23    XTZ-USD  12.087792
# 29    SRM-USD   9.363540
# 27  SUSHI-USD   9.324484
# 22    ETC-USD   9.168004
# 15    BCH-USD   6.777316
# 7    DOT1-USD   6.659740
# 14    LTC-USD   6.216492
# 28    CRV-USD   6.125508
# 18    FIL-USD   5.516267
# 21  ATOM1-USD   4.826681
# 5     XRP-USD   4.508765
# 25   HBAR-USD   4.064861
# 1     ETH-USD   3.926723
# 19    XLM-USD   3.753357
# 3     BNB-USD   3.468089
# 10   UNI3-USD   2.181444
# 20    TRX-USD   1.229669
# 24    EOS-USD   1.150038
# 17  MATIC-USD   0.340270
# 9    USDC-USD  -0.027051
# 4    USDT-USD  -0.028659
# 0     BTC-USD  -0.607037
# 26   SHIB-USD  -3.276848

# %%
MultipleActionTest.ticker_list
